# %% [markdown]
# <a href="https://colab.research.google.com/github/Arwa678/IT326-Group-1/blob/main/Phase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # About the project
# In our project, we chose the **Heart Health dataset** because heart disease is one of the leading causes of death worldwide.
# Understanding the factors that contribute to heart disease is crucial for prevention. The dataset provides important information such as
# age, gender, blood pressure, cholesterol levels, and other health-related factors which are key indicators of heart health.
#
# By analyzing this data, we hope to identify patterns and risk factors that can help predict heart disease.
# This could be valuable for healthcare professionals in developing strategies to prevent heart disease and improve patient care.
# Our goal is to contribute to better heart health by using data to spot trends and offer insights into managing heart disease risk.

# %% [markdown]
# ## Dataset Source:
# The Heart Health dataset is provided for research and analysis to better understand the risk factors contributing to heart disease.
# ## Goal:
# The goal of this dataset is to predict the likelihood of a heart attack based on various health metrics, including blood pressure, cholesterol, glucose levels# smoking habits, and exercise patterns. This analysis will aid in early detection and prevention strategies for heart disease.

# %%
import pandas as pd
dataset_path = 'https://raw.githubusercontent.com/Arwa678/IT326-Group-/main/Dataset/Heart_health.csv'

# %%
column_names = ['ID', 'Name', 'Age', 'Gender', 'Height(cm)', 'Weight(kg)', 'Blood Pressure(mmHg)',
                'Cholesterol(mg/dL)', 'Glucose(mg/dL)', 'Smoker', 'Exercise(hours/week)', 'Heart Attack']

# %%
df = pd.read_csv(dataset_path, names=column_names)
df.head()
# Out:
#    ID             Name  Age  Gender  Height(cm)  Weight(kg)  \
# 0  ID             Name  Age  Gender  Height(cm)  Weight(kg)
# 1   1         John Doe   45    Male         175          80
# 2   2       Jane Smith   35  Female         160          65
# 3   3  Michael Johnson   55    Male         180          85
# 4   4      Sarah Brown   40  Female         165          70
#
#    Blood Pressure(mmHg)  Cholesterol(mg/dL)  Glucose(mg/dL)  Smoker  \
# 0  Blood Pressure(mmHg)  Cholesterol(mg/dL)  Glucose(mg/dL)  Smoker
# 1                120/80                 200              90      No
# 2                110/70                 180              80      No
# 3                130/85                 220              95     Yes
# 4                115/75                 190              85      No
#
#    Exercise(hours/week)  Heart Attack
# 0  Exercise(hours/week)  Heart Attack
# 1                     3             0
# 2                     2             0
# 3                     4             1
# 4                     3             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725 entries, 0 to 724
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    725 non-null    object
#  1   Name                  725 non-null    object
#  2   Age                   725 non-null    object
#  3   Gender                725 non-null    object
#  4   Height(cm)            725 non-null    object
#  5   Weight(kg)            725 non-null    object
#  6   Blood Pressure(mmHg)  725 non-null    object
#  7   Cholesterol(mg/dL)    725 non-null    object
#  8   Glucose(mg/dL)        725 non-null    object
#  9   Smoker                725 non-null    object
#  10  Exercise(hours/week)  725 non-null    object
#  11  Heart Attack          725 non-null    object
# dtypes: object(12)
# memory usage: 68.1+ KB

# %%
df.describe(include='all')
# Out:
#          ID       Name  Age Gender Height(cm) Weight(kg) Blood Pressure(mmHg)  \
# count   725        725  725    725        725        725                  725
# unique  715        122   32      3         30         30                   41
# top     667  David Kim   47   Male        170         79               125/80
# freq      2         38   59    362        109         80                   86
#
#        Cholesterol(mg/dL) Glucose(mg/dL) Smoker Exercise(hours/week)  \
# count                 725            725    725                  725
# unique                 14             15      3                    5
# top                   210             88     No                    2
# freq                  189            193    376                  250
#
#        Heart Attack
# count           725
# unique            3
# top               1
# freq            434
